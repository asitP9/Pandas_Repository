# %% [markdown]
# ## ROW WISE

# %%
import pandas as pd

# %%
pd.read_csv("stocks1.csv")
# Out:
#          Date   Close    Volume Symbol
# 0  2016-10-03   31.50  14070500   CSCO
# 1  2016-10-03  112.52  21701800   AAPL
# 2  2016-10-03   57.42  19189500   MSFT

# %%
pd.read_csv("stocks2.csv")
# Out:
#          Date   Close    Volume Symbol
# 0  2016-10-04  113.00  29736800   AAPL
# 1  2016-10-04   57.24  20085900   MSFT
# 2  2016-10-04   31.35  18460400   CSCO

# %%
pd.read_csv("stocks3.csv")
# Out:
#          Date   Close    Volume Symbol
# 0  2016-10-05   57.64  16726400   MSFT
# 1  2016-10-05   31.59  11808600   CSCO
# 2  2016-10-05  113.05  21453100   AAPL

# %%
from glob import glob
stock_files=sorted(glob('stocks*.csv'))

# %%
stock_files
# Out:
# ['stocks.csv', 'stocks1.csv', 'stocks2.csv', 'stocks3.csv']

# %%
pd.concat(pd.read_csv(file) for file in stock_files)
# Out:
#          Date   Close    Volume Symbol
# 0  2016-10-03   31.50  14070500   CSCO
# 1  2016-10-03  112.52  21701800   AAPL
# 2  2016-10-03   57.42  19189500   MSFT
# 3  2016-10-04  113.00  29736800   AAPL
# 4  2016-10-04   57.24  20085900   MSFT
# 5  2016-10-04   31.35  18460400   CSCO
# 6  2016-10-05   57.64  16726400   MSFT
# 7  2016-10-05   31.59  11808600   CSCO
# 8  2016-10-05  113.05  21453100   AAPL
# 0  2016-10-03   31.50  14070500   CSCO
# 1  2016-10-03  112.52  21701800   AAPL
# 2  2016-10-03   57.42  19189500   MSFT
# 0  2016-10-04  113.00  29736800   AAPL
# 1  2016-10-04   57.24  20085900   MSFT
# 2  2016-10-04   31.35  18460400   CSCO
# 0  2016-10-05   57.64  16726400   MSFT
# 1  2016-10-05   31.59  11808600   CSCO
# 2  2016-10-05  113.05  21453100   AAPL

# %%
pd.concat((pd.read_csv(file) for file in stock_files), ignore_index=True)
# Out:
#           Date   Close    Volume Symbol
# 0   2016-10-03   31.50  14070500   CSCO
# 1   2016-10-03  112.52  21701800   AAPL
# 2   2016-10-03   57.42  19189500   MSFT
# 3   2016-10-04  113.00  29736800   AAPL
# 4   2016-10-04   57.24  20085900   MSFT
# 5   2016-10-04   31.35  18460400   CSCO
# 6   2016-10-05   57.64  16726400   MSFT
# 7   2016-10-05   31.59  11808600   CSCO
# 8   2016-10-05  113.05  21453100   AAPL
# 9   2016-10-03   31.50  14070500   CSCO
# 10  2016-10-03  112.52  21701800   AAPL
# 11  2016-10-03   57.42  19189500   MSFT
# 12  2016-10-04  113.00  29736800   AAPL
# 13  2016-10-04   57.24  20085900   MSFT
# 14  2016-10-04   31.35  18460400   CSCO
# 15  2016-10-05   57.64  16726400   MSFT
# 16  2016-10-05   31.59  11808600   CSCO
# 17  2016-10-05  113.05  21453100   AAPL

# %% [markdown]
# ## COLUMN WISE

# %%
pd.read_csv("drinks1.csv")
# Out:
#          country  beer_servings  spirit_servings
# 0    Afghanistan              0                0
# 1        Albania             89              132
# 2        Algeria             25                0
# 3        Andorra            245              138
# 4         Angola            217               57
# ..           ...            ...              ...
# 188    Venezuela            333              100
# 189      Vietnam            111                2
# 190        Yemen              6                0
# 191       Zambia             32               19
# 192     Zimbabwe             64               18
#
# [193 rows x 3 columns]

# %%
pd.read_csv("drinks2.csv")
# Out:
#      wine_servings  total_litres_of_pure_alcohol      continent
# 0                0                           0.0           Asia
# 1               54                           4.9         Europe
# 2               14                           0.7         Africa
# 3              312                          12.4         Europe
# 4               45                           5.9         Africa
# ..             ...                           ...            ...
# 188              3                           7.7  South America
# 189              1                           2.0           Asia
# 190              0                           0.1           Asia
# 191              4                           2.5         Africa
# 192              4                           4.7         Africa
#
# [193 rows x 3 columns]

# %%
from glob import glob
stock_files=sorted(glob('drinks*.csv'))

# %%
stock_files
# Out:
# ['drinks.csv', 'drinks1.csv', 'drinks2.csv']

# %%
stock_files.pop(0)
# Out:
# 'drinks.csv'

# %%
stock_files
# Out:
# ['drinks1.csv', 'drinks2.csv']

# %%
pd.concat((pd.read_csv(files) for files in stock_files), axis=1).head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa
